# %%
# Import dependencies

import pandas as pd
import psycopg2
import json
from sqlalchemy import create_engine
from config import my_password

# %%
# Read dog adoptions DataFrame from PostgreSQL
db_string = f"postgresql://postgres:{my_password}@127.0.0.1:5432/PetFindingDB"
engine = create_engine(db_string)
dog_adoptions = pd.read_sql("select * from \"dog_adoptions\"", con=engine)
dog_adoptions.head()
# Out:
#    index        id organization_id  \
# 0      0  55441061           wi482
# 1      1  55436505           wi533
# 2      2  55433679           al278
# 3      3  55429606           wi523
# 4      4  55429346           wi523
#
#                                                  url type species     age  \
# 0  https://www.petfinder.com/dog/max-55441061/wi/...  Dog     Dog   Adult
# 1  https://www.petfinder.com/dog/miles-55436505/w...  Dog     Dog  Senior
# 2  https://www.petfinder.com/dog/dorothy-55433679...  Dog     Dog   Adult
# 3  https://www.petfinder.com/dog/kondor-55429606/...  Dog     Dog   Young
# 4  https://www.petfinder.com/dog/aspen-55429346/w...  Dog     Dog    Baby
#
#    gender    size   coat  ... contact.phone contact.address.address1  \
# 0    Male   Small   None  ...          None                     None
# 1    Male   Small   None  ...          None                     None
# 2  Female  Medium   None  ...          None                     None
# 3    Male   Large  Short  ...          None                     None
# 4  Female  Medium  Short  ...          None                     None
#
#   contact.address.address2 contact.address.city contact.address.state  \
# 0                     None           Beaver Dam                    WI
# 1                     None           New London                    WI
# 2                     None                Ripon                    WI
# 3                     None                 Alma                    WI
# 4                     None                 Alma                    WI
#
#   contact.address.postcode contact.address.country animal_id animal_type  \
# 0                    53916                      US  55441061         dog
# 1                    54961                      US  55436505         dog
# 2                    54971                      US  55433679         dog
# 3                    54610                      US  55429606         dog
# 4                    54610                      US  55429346         dog
#
#    primary_photo_cropped
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
#
# [5 rows x 50 columns]

# %%
# Drop index column
dog_adoptions = dog_adoptions.drop('index', 1)
dog_adoptions.head()
# Out:
# C:\Users\m212193\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#          id organization_id  \
# 0  55441061           wi482
# 1  55436505           wi533
# 2  55433679           al278
# 3  55429606           wi523
# 4  55429346           wi523
#
#                                                  url type species     age  \
# 0  https://www.petfinder.com/dog/max-55441061/wi/...  Dog     Dog   Adult
# 1  https://www.petfinder.com/dog/miles-55436505/w...  Dog     Dog  Senior
# 2  https://www.petfinder.com/dog/dorothy-55433679...  Dog     Dog   Adult
# 3  https://www.petfinder.com/dog/kondor-55429606/...  Dog     Dog   Young
# 4  https://www.petfinder.com/dog/aspen-55429346/w...  Dog     Dog    Baby
#
#    gender    size   coat                                               tags  \
# 0    Male   Small   None                                                 []
# 1    Male   Small   None                                                 []
# 2  Female  Medium   None                                                 []
# 3    Male   Large  Short  ["Friendly", "Affectionate", "Loyal", "Playful...
# 4  Female  Medium  Short              ["Friendly", "Affectionate", "Smart"]
#
#    ... contact.phone contact.address.address1 contact.address.address2  \
# 0  ...          None                     None                     None
# 1  ...          None                     None                     None
# 2  ...          None                     None                     None
# 3  ...          None                     None                     None
# 4  ...          None                     None                     None
#
#   contact.address.city contact.address.state contact.address.postcode  \
# 0           Beaver Dam                    WI                    53916
# 1           New London                    WI                    54961
# 2                Ripon                    WI                    54971
# 3                 Alma                    WI                    54610
# 4                 Alma                    WI                    54610
#
#   contact.address.country animal_id  animal_type primary_photo_cropped
# 0                      US  55441061          dog                  None
# 1                      US  55436505          dog                  None
# 2                      US  55433679          dog                  None
# 3                      US  55429606          dog                  None
# 4                      US  55429346          dog                  None
#
# [5 rows x 49 columns]

# %%
# Get length of all_dogs DataFrame

len(dog_adoptions.index)
# Out:
# 150700

# %%
# Determine data types

dog_adoptions.dtypes
# Out:
# id                                int64
# organization_id                  object
# url                              object
# type                             object
# species                          object
# age                              object
# gender                           object
# size                             object
# coat                             object
# tags                             object
# name                             object
# description                      object
# organization_animal_id           object
# photos                           object
# videos                           object
# status                           object
# status_changed_at                object
# published_at                     object
# distance                        float64
# breeds.primary                   object
# breeds.secondary                 object
# breeds.mixed                       bool
# breeds.unknown                     bool
# colors.primary                   object
# colors.secondary                 object
# colors.tertiary                  object
# attributes.spayed_neutered         bool
# attributes.house_trained           bool
# attributes.declawed              object
# attributes.special_needs           bool
# attributes.shots_current           bool
# environment.children             object
# environment.dogs                 object
# environment.cats                 object
# primary_photo_cropped.small      object
# primary_photo_cropped.medium     object
# primary_photo_cropped.large      object
# primary_photo_cropped.full       object
# contact.email                    object
# contact.phone                    object
# contact.address.address1         object
# contact.address.address2         object
# contact.address.city             object
# contact.address.state            object
# contact.address.postcode         object
# contact.address.country          object
# animal_id                        object
# animal_type                      object
# primary_photo_cropped            object
# dtype: object

# %%
# See NaN values

dog_adoptions.isna().sum(axis=0)
# Out:
# id                                   0
# organization_id                      0
# url                                  0
# type                                 0
# species                              0
# age                                  0
# gender                               0
# size                                 0
# coat                             34336
# tags                                 0
# name                                36
# description                      10873
# organization_animal_id          121427
# photos                               0
# videos                               0
# status                               0
# status_changed_at                    0
# published_at                         0
# distance                             0
# breeds.primary                       0
# breeds.secondary                104435
# breeds.mixed                         0
# breeds.unknown                       0
# colors.primary                   40411
# colors.secondary                 96040
# colors.tertiary                 144960
# attributes.spayed_neutered           0
# attributes.house_trained             0
# attributes.declawed             150700
# attributes.special_needs             0
# attributes.shots_current             0
# environment.children             74498
# environment.dogs                 57387
# environment.cats                 99465
# primary_photo_cropped.small       2407
# primary_photo_cropped.medium      2407
# primary_photo_cropped.large       2407
# primary_photo_cropped.full        2407
# contact.email                     9208
# contact.phone                    36544
# contact.address.address1         55641
# contact.address.address2        133956
# contact.address.city                 0
# contact.address.state                0
# contact.address.postcode             0
# contact.address.country              0
# animal_id                            0
# animal_type                          0
# primary_photo_cropped           150700
# dtype: int64

# %%
# Create new dataframe with only the desired columns

clean_dogs = dog_adoptions[['id', 'organization_id', 'breeds.primary', 'breeds.mixed', 'age', 'gender', 'size', 'attributes.spayed_neutered', 'attributes.house_trained', 'attributes.special_needs', 'attributes.shots_current', 'status_changed_at', 'published_at',]].copy()
clean_dogs.head()
# Out:
#          id organization_id breeds.primary  breeds.mixed     age  gender  \
# 0  55441061           wi482         Beagle          True   Adult    Male
# 1  55436505           wi533    Rat Terrier          True  Senior    Male
# 2  55433679           al278    Mixed Breed          True   Adult  Female
# 3  55429606           wi523       Shepherd          True   Young    Male
# 4  55429346           wi523        Terrier          True    Baby  Female
#
#      size  attributes.spayed_neutered  attributes.house_trained  \
# 0   Small                        True                      True
# 1   Small                        True                     False
# 2  Medium                        True                      True
# 3   Large                        True                      True
# 4  Medium                        True                      True
#
#    attributes.special_needs  attributes.shots_current  \
# 0                     False                      True
# 1                     False                      True
# 2                     False                      True
# 3                     False                      True
# 4                     False                      True
#
#           status_changed_at              published_at
# 0  2022-05-07T15:33:13+0000  2022-04-29T18:47:59+0000
# 1  2022-05-03T09:21:06+0000  2022-04-29T12:35:17+0000
# 2  2022-05-04T23:14:47+0000  2022-04-28T23:27:25+0000
# 3  2022-04-30T16:50:03+0000  2022-04-28T18:07:08+0000
# 4  2022-04-30T22:48:39+0000  2022-04-28T17:48:45+0000

# %%
# Drop any rows with NaN values and confirm they have been dropped
clean_dogs.dropna(how='any')
clean_dogs.isna().sum(axis=0)
# Out:
# id                            0
# organization_id               0
# breeds.primary                0
# breeds.mixed                  0
# age                           0
# gender                        0
# size                          0
# attributes.spayed_neutered    0
# attributes.house_trained      0
# attributes.special_needs      0
# attributes.shots_current      0
# status_changed_at             0
# published_at                  0
# dtype: int64

# %%
# Get length of clean_dogs DataFrame

len(clean_dogs.index)
# Out:
# 150700

# %%
# Change status changed at (to adopted) and published at to datetime and subtract to calculate length of stay

clean_dogs[['status_changed_at', 'published_at']] = clean_dogs[['status_changed_at', 'published_at']].apply(pd.to_datetime)
clean_dogs['duration'] = (clean_dogs['status_changed_at'] - clean_dogs['published_at']).dt.days
clean_dogs.head()
# Out:
#          id organization_id breeds.primary  breeds.mixed     age  gender  \
# 0  55441061           wi482         Beagle          True   Adult    Male
# 1  55436505           wi533    Rat Terrier          True  Senior    Male
# 2  55433679           al278    Mixed Breed          True   Adult  Female
# 3  55429606           wi523       Shepherd          True   Young    Male
# 4  55429346           wi523        Terrier          True    Baby  Female
#
#      size  attributes.spayed_neutered  attributes.house_trained  \
# 0   Small                        True                      True
# 1   Small                        True                     False
# 2  Medium                        True                      True
# 3   Large                        True                      True
# 4  Medium                        True                      True
#
#    attributes.special_needs  attributes.shots_current  \
# 0                     False                      True
# 1                     False                      True
# 2                     False                      True
# 3                     False                      True
# 4                     False                      True
#
#           status_changed_at              published_at  duration
# 0 2022-05-07 15:33:13+00:00 2022-04-29 18:47:59+00:00         7
# 1 2022-05-03 09:21:06+00:00 2022-04-29 12:35:17+00:00         3
# 2 2022-05-04 23:14:47+00:00 2022-04-28 23:27:25+00:00         5
# 3 2022-04-30 16:50:03+00:00 2022-04-28 18:07:08+00:00         1
# 4 2022-04-30 22:48:39+00:00 2022-04-28 17:48:45+00:00         2

# %%
# Drop status_changed_at and published_at columns
clean_dogs = clean_dogs.drop(['status_changed_at', 'published_at'], axis=1)
clean_dogs.head()
# Out:
#          id organization_id breeds.primary  breeds.mixed     age  gender  \
# 0  55441061           wi482         Beagle          True   Adult    Male
# 1  55436505           wi533    Rat Terrier          True  Senior    Male
# 2  55433679           al278    Mixed Breed          True   Adult  Female
# 3  55429606           wi523       Shepherd          True   Young    Male
# 4  55429346           wi523        Terrier          True    Baby  Female
#
#      size  attributes.spayed_neutered  attributes.house_trained  \
# 0   Small                        True                      True
# 1   Small                        True                     False
# 2  Medium                        True                      True
# 3   Large                        True                      True
# 4  Medium                        True                      True
#
#    attributes.special_needs  attributes.shots_current  duration
# 0                     False                      True         7
# 1                     False                      True         3
# 2                     False                      True         5
# 3                     False                      True         1
# 4                     False                      True         2

# %%
# Drop all rows with a length of stay of 0

clean_dogs = clean_dogs[clean_dogs['duration'] > 0]
clean_dogs.head()
# Out:
#          id organization_id breeds.primary  breeds.mixed     age  gender  \
# 0  55441061           wi482         Beagle          True   Adult    Male
# 1  55436505           wi533    Rat Terrier          True  Senior    Male
# 2  55433679           al278    Mixed Breed          True   Adult  Female
# 3  55429606           wi523       Shepherd          True   Young    Male
# 4  55429346           wi523        Terrier          True    Baby  Female
#
#      size  attributes.spayed_neutered  attributes.house_trained  \
# 0   Small                        True                      True
# 1   Small                        True                     False
# 2  Medium                        True                      True
# 3   Large                        True                      True
# 4  Medium                        True                      True
#
#    attributes.special_needs  attributes.shots_current  duration
# 0                     False                      True         7
# 1                     False                      True         3
# 2                     False                      True         5
# 3                     False                      True         1
# 4                     False                      True         2

# %%
# Get length of clean_dogs DataFrame

len(clean_dogs.index)
# Out:
# 140636

# %%
# Rename the columns
clean_dogs.columns = ['dog_id', 'organization_id', 'primary_breed', 'mixed_breed', 'age', 'gender', 'size', 'spayed_neutered', 'house_trained', 'special_needs', 'shots_current', 'duration']
clean_dogs.head()
# Out:
#      dog_id organization_id primary_breed  mixed_breed     age  gender  \
# 0  55441061           wi482        Beagle         True   Adult    Male
# 1  55436505           wi533   Rat Terrier         True  Senior    Male
# 2  55433679           al278   Mixed Breed         True   Adult  Female
# 3  55429606           wi523      Shepherd         True   Young    Male
# 4  55429346           wi523       Terrier         True    Baby  Female
#
#      size  spayed_neutered  house_trained  special_needs  shots_current  \
# 0   Small             True           True          False           True
# 1   Small             True          False          False           True
# 2  Medium             True           True          False           True
# 3   Large             True           True          False           True
# 4  Medium             True           True          False           True
#
#    duration
# 0         7
# 1         3
# 2         5
# 3         1
# 4         2

# %%
# Read clean dogs DataFrame into PostgreSQL and as a csv file
db_string = f"postgresql://postgres:{my_password}@127.0.0.1:5432/PetFindingDB"
engine = create_engine(db_string)
clean_dogs.to_sql(name='clean_dog_adoptions', con=engine, if_exists='replace')
clean_dogs.to_csv('Resources/adoptions_list.csv', index=False)

# %%
# Read organizations DataFrame from PostgreSQL
db_string = f"postgresql://postgres:{my_password}@127.0.0.1:5432/PetFindingDB"
engine = create_engine(db_string)
organizations = pd.read_sql("select * from \"organizations\"", con=engine)
organizations.head()
# Out:
#    index organization_id                                  organization_name  \
# 0      0           MO556  Montgomery City Animal Shelter/Project Preciou...
# 1      1           MN443                               Kitten Care Group MN
# 2      2           OH459                               Second Chance Rescue
# 3      3            MO30                       Second Chance Sheltie Rescue
# 4      4            MI51                                  SOS Animal Rescue
#
#                 organization_email organization_phone  \
# 0  projectpreciouspaws@hotmail.com     1-573-310-4979
# 1      kittencaregroupmn@gmail.com               None
# 2          secchancerescue@aol.com               None
# 3     sheltierescue@sheltie4me.com     888 873 5443
# 4                   info@sosar.org     (989) 492-0042
#
#                                                  url  \
# 0  https://www.petfinder.com/member/us/mo/montgom...
# 1  https://www.petfinder.com/member/us/mn/kasota/...
# 2  https://www.petfinder.com/member/us/oh/bellbro...
# 3  https://www.petfinder.com/member/us/mo/marylan...
# 4  https://www.petfinder.com/member/us/mi/midland...
#
#                           website  \
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4  http://www.sosanimalrescue.org
#
#                                    mission_statement  \
# 0                                               None
# 1                                               None
# 2  Second Chance Rescue is a non-profit organizat...
# 3                                               None
# 4  To reduce the number of unwanted pets in the M...
#
#                                               photos  distance  ...  \
# 0  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  681.5435  ...
# 1  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  344.9607  ...
# 2  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  750.9111  ...
# 3  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  696.9796  ...
# 4  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  457.4366  ...
#
#   hours_saturday hours_sunday  \
# 0           None         None
# 1           None         None
# 2           None         None
# 3           None         None
# 4           None         None
#
#                                      adoption_policy adoption_url  \
# 0                                               None         None
# 1                                               None         None
# 2  Adopting A Friend:\r\n\r\nIf you see an animal...         None
# 3                                               None         None
# 4                                               None         None
#
#                                         sm_facebook sm_twitter  \
# 0                                              None       None
# 1                                              None       None
# 2  http://www.facebook.com/secondchancerescuedayton       None
# 3                                              None       None
# 4                                              None       None
#
#                                     sm_youtube sm_instagram sm_pinterest  \
# 0                                         None         None         None
# 1                                         None         None         None
# 2  https://www.youtube.com/watch?v=ybN50aRZjq0         None         None
# 3                                         None         None         None
# 4                                         None         None         None
#
#   organization_id2
# 0            mo556
# 1            mn443
# 2            oh459
# 3             mo30
# 4             mi51
#
# [5 rows x 31 columns]

# %%
# Drop index column
organizations = organizations.drop('index', 1)
organizations.head()
# Out:
# C:\Users\m212193\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   organization_id                                  organization_name  \
# 0           MO556  Montgomery City Animal Shelter/Project Preciou...
# 1           MN443                               Kitten Care Group MN
# 2           OH459                               Second Chance Rescue
# 3            MO30                       Second Chance Sheltie Rescue
# 4            MI51                                  SOS Animal Rescue
#
#                 organization_email organization_phone  \
# 0  projectpreciouspaws@hotmail.com     1-573-310-4979
# 1      kittencaregroupmn@gmail.com               None
# 2          secchancerescue@aol.com               None
# 3     sheltierescue@sheltie4me.com     888 873 5443
# 4                   info@sosar.org     (989) 492-0042
#
#                                                  url  \
# 0  https://www.petfinder.com/member/us/mo/montgom...
# 1  https://www.petfinder.com/member/us/mn/kasota/...
# 2  https://www.petfinder.com/member/us/oh/bellbro...
# 3  https://www.petfinder.com/member/us/mo/marylan...
# 4  https://www.petfinder.com/member/us/mi/midland...
#
#                           website  \
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4  http://www.sosanimalrescue.org
#
#                                    mission_statement  \
# 0                                               None
# 1                                               None
# 2  Second Chance Rescue is a non-profit organizat...
# 3                                               None
# 4  To reduce the number of unwanted pets in the M...
#
#                                               photos  distance  \
# 0  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  681.5435
# 1  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  344.9607
# 2  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  750.9111
# 3  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  696.9796
# 4  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  457.4366
#
#            address_1  ... hours_saturday hours_sunday  \
# 0  915 Benton Street  ...           None         None
# 1               None  ...           None         None
# 2               None  ...           None         None
# 3     P. O. Box 1791  ...           None         None
# 4        PO Box 1135  ...           None         None
#
#                                      adoption_policy adoption_url  \
# 0                                               None         None
# 1                                               None         None
# 2  Adopting A Friend:\r\n\r\nIf you see an animal...         None
# 3                                               None         None
# 4                                               None         None
#
#                                         sm_facebook sm_twitter  \
# 0                                              None       None
# 1                                              None       None
# 2  http://www.facebook.com/secondchancerescuedayton       None
# 3                                              None       None
# 4                                              None       None
#
#                                     sm_youtube sm_instagram sm_pinterest  \
# 0                                         None         None         None
# 1                                         None         None         None
# 2  https://www.youtube.com/watch?v=ybN50aRZjq0         None         None
# 3                                         None         None         None
# 4                                         None         None         None
#
#   organization_id2
# 0            mo556
# 1            mn443
# 2            oh459
# 3             mo30
# 4             mi51
#
# [5 rows x 30 columns]

# %%
# Create new DataFrame with only organizations in Wisconsin

wisconsin_organizations = organizations[organizations['organization_id'].str.startswith('W')]
wisconsin_organizations
# Out:
#      organization_id                           organization_name  \
# 9              WI291            Great Pyrenees Rescue of WI. Inc
# 20             WI535                     Mecca's Pit Bull Rescue
# 26             WI517                       Passion for Paws, LLC
# 47             WI129  Feathered Friends Sanctuary & Rescue, Inc.
# 52             WI392        American Brittany Rescue-WI/MN/SD/ND
# ...              ...                                         ...
# 2375           WI507          Humane Society of Sheboygan County
# 2384            WI03                  Rusk County Animal Shelter
# 2390           WI164                       RoseBerry Bird Rescue
# 2391           WI136               Shih Tzu Rescue of Central WI
# 2393           WI426                   Fisher Valley Felines Inc
#
#                      organization_email organization_phone  \
# 9                   wooflodge@yahoo.com     (920) 293-8885
# 20        meccaspitbullrescue@gmail.com     (920) 627-6727
# 26            vetoffice@pawsmadison.com     (608) 826-3700
# 47                birdlover7978@att.net       608-302-1732
# 52    abr.wi@americanbrittanyrescue.org     (866) 274-8911
# ...                                 ...                ...
# 2375              adoptions@scadopt.org     (920) 458-2012
# 2384        ruskanimals@ruskcountywi.us     (715) 532-2637
# 2390      RoseBerryBirdRescue@gmail.com     (920) 574-8305
# 2391                   rlasings@aol.com     (715) 241-7328
# 2393    fishervalleyfelines@charter.net     (608) 516-3034
#
#                                                     url  \
# 9     https://www.petfinder.com/member/us/wi/neshkor...
# 20    https://www.petfinder.com/member/us/wi/sheboyg...
# 26    https://www.petfinder.com/member/us/wi/madison...
# 47    https://www.petfinder.com/member/us/wi/edgerto...
# 52    https://www.petfinder.com/member/us/wi/manitow...
# ...                                                 ...
# 2375  https://www.petfinder.com/member/us/wi/sheboyg...
# 2384  https://www.petfinder.com/member/us/wi/ladysmi...
# 2390  https://www.petfinder.com/member/us/wi/neenah/...
# 2391  https://www.petfinder.com/member/us/wi/schofie...
# 2393  https://www.petfinder.com/member/us/wi/fitchbu...
#
#                                        website  \
# 9              http://www.greatpyrrescuewi.com
# 20         https://www.meccaspitbullrescue.com
# 26                 http://www.pfpvcmadison.com
# 47                                        None
# 52                                        None
# ...                                        ...
# 2375         https://adoptsheboygancounty.org/
# 2384               https://www.ruskanimals.com
# 2390        http://www.roseberrybirdrescue.org
# 2391  https://www.shihtzurescueofcentralwi.org
# 2393        http://www.fishervalleyfelines.com
#
#                                       mission_statement  \
# 9                                                  None
# 20    Our mission is to rescue and assist Pit Bull- ...
# 26    To provide the best patient and client care wi...
# 47                                                 None
# 52                                                 None
# ...                                                 ...
# 2375  The prevention of cruelty to animals, \r\nthe ...
# 2384                                               None
# 2390  RoseBerry Bird Rescue is committed to enhancin...
# 2391  We are an all volunteer organization dedicated...
# 2393  If you are looking for a cat or kitten or a PA...
#
#                                                  photos  distance  \
# 9                                                    []  119.1883
# 20    [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  208.1302
# 26    [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  215.9359
# 47                                                   []  243.7832
# 52                                                   []  187.3634
# ...                                                 ...       ...
# 2375  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  205.0458
# 2384  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  121.7345
# 2390                                                 []  131.2339
# 2391  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...   10.1428
# 2393  [{"small": "https://dl5zpyw5k3jeb.cloudfront.n...  219.4521
#
#                address_1  ...                            hours_saturday  \
# 9                   None  ...                                      None
# 20                  None  ...                                      None
# 26    437 S. Junction Rd  ...                                      None
# 47      1570 County Rd A  ...                                      None
# 52       2425 Stone Road  ...                                      None
# ...                  ...  ...                                       ...
# 2375  3209 N 21st Street  ...                          12:00pm - 4:00pm
# 2384      200 Doughty Rd  ...  10 am to 2 pm every 1st and 3rd Saturday
# 2390                None  ...                                      None
# 2391                None  ...                                      None
# 2393                None  ...                                      None
#
#           hours_sunday                                    adoption_policy  \
# 9                 None                                               None
# 20                None  Mecca&#039;s Pit Bull Rescue requires for an a...
# 26                None                                               None
# 47                None                                               None
# 52                None                                               None
# ...                ...                                                ...
# 2375  12:00pm - 4:00pm  Search available pets at your local shelter - ...
# 2384              None                                               None
# 2390              None  Please visit our website to learn more about o...
# 2391              None  Adoption applications are available on our web...
# 2393              None  If you are interested in adopting......\n\n1. ...
#
#                                            adoption_url  \
# 9                                                  None
# 20                                                 None
# 26                                                 None
# 47                                                 None
# 52                                                 None
# ...                                                 ...
# 2375            https://adoptsheboygancounty.org/adopt/
# 2384                                               None
# 2390                                               None
# 2391                                               None
# 2393  http://www.fishervalleyfelines.com/docs/Online...
#
#                                             sm_facebook sm_twitter sm_youtube  \
# 9                                                  None       None       None
# 20         https://www.facebook.com/meccaspitbullrescue       None       None
# 26                    http://www.facebook.com/paws53719       None       None
# 47                                                 None       None       None
# 52                                                 None       None       None
# ...                                                 ...        ...        ...
# 2375                                               None       None       None
# 2384  https://www.facebook.com/profile.php?id=100064...       None       None
# 2390         https://facebook.com/roseberry.birdrescue/       None       None
# 2391                                               None       None       None
# 2393      https://www.facebook.com/FisherValleyFelines/       None       None
#
#      sm_instagram sm_pinterest organization_id2
# 9            None         None            wi291
# 20           None         None            wi535
# 26           None         None            wi517
# 47           None         None            wi129
# 52           None         None            wi392
# ...           ...          ...              ...
# 2375         None         None            wi507
# 2384         None         None             wi03
# 2390         None         None            wi164
# 2391         None         None            wi136
# 2393         None         None            wi426
#
# [204 rows x 30 columns]

# %%
# Remove unnecessary columns

wisconsin_organizations = wisconsin_organizations[['organization_id', 'organization_name', 'organization_email', 'organization_phone', 'url', 'website', 'address_1']].reset_index(drop=True)
wisconsin_organizations.head()
# Out:
#   organization_id                           organization_name  \
# 0           WI291            Great Pyrenees Rescue of WI. Inc
# 1           WI535                     Mecca's Pit Bull Rescue
# 2           WI517                       Passion for Paws, LLC
# 3           WI129  Feathered Friends Sanctuary & Rescue, Inc.
# 4           WI392        American Brittany Rescue-WI/MN/SD/ND
#
#                   organization_email organization_phone  \
# 0                wooflodge@yahoo.com     (920) 293-8885
# 1      meccaspitbullrescue@gmail.com     (920) 627-6727
# 2          vetoffice@pawsmadison.com     (608) 826-3700
# 3              birdlover7978@att.net       608-302-1732
# 4  abr.wi@americanbrittanyrescue.org     (866) 274-8911
#
#                                                  url  \
# 0  https://www.petfinder.com/member/us/wi/neshkor...
# 1  https://www.petfinder.com/member/us/wi/sheboyg...
# 2  https://www.petfinder.com/member/us/wi/madison...
# 3  https://www.petfinder.com/member/us/wi/edgerto...
# 4  https://www.petfinder.com/member/us/wi/manitow...
#
#                                website           address_1
# 0      http://www.greatpyrrescuewi.com                None
# 1  https://www.meccaspitbullrescue.com                None
# 2          http://www.pfpvcmadison.com  437 S. Junction Rd
# 3                                 None    1570 County Rd A
# 4                                 None     2425 Stone Road

# %%
# Read Wisconsin organizations DataFrame into PostgreSQL and as a csv file
db_string = f"postgresql://postgres:{my_password}@127.0.0.1:5432/PetFindingDB"
engine = create_engine(db_string)
wisconsin_organizations.to_sql(name='wisconsin_organizations', con=engine, if_exists='replace')

# %%
# Import dependencies

import petpy as pt
from config import petfinder_api_key
from config import petfinder_secret

# %%
# Initiate petpy

pf = pt.Petfinder(key=petfinder_api_key, secret=petfinder_secret)

# %%
# Make API call

pet_data = pf.animals(animal_type='dog', status='adopted', results_per_page=100, pages=200, location=54701, before_date='2022-05-01', after_date='2021-05-01', return_df=True)
# Out:
# pages parameter exceeded maximum number of available pages available from the Petfinder API. As a result, the maximum number of pages 75 was returned

# %%
# View data obtained from the API call

pet_data.head()
# Out:
#          id  organization_id  \
# 0  55454849            MN330
# 1  55454847            MN330
# 2  55454846            MN330
# 3  55454848            MN330
# 4  55454844            MN330
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/dog/mork-55454849/mn...  Dog     Dog   Baby
# 1  https://www.petfinder.com/dog/jessie-55454847/...  Dog     Dog  Adult
# 2  https://www.petfinder.com/dog/tilin-55454846/m...  Dog     Dog  Young
# 3  https://www.petfinder.com/dog/apollo-55454848/...  Dog     Dog  Adult
# 4  https://www.petfinder.com/dog/mindy-55454844/m...  Dog     Dog   Baby
#
#    gender    size  coat tags  ... contact.address.address1  \
# 0    Male   Large  None   []  ...             PO Box 29461
# 1    Male   Large  None   []  ...             PO Box 29461
# 2    Male  Medium  None   []  ...             PO Box 29461
# 3    Male  Medium  None   []  ...             PO Box 29461
# ...

# %%
# View data types

pet_data.dtypes
# Out:
# id                                int64
# organization_id                  object
# url                              object
# type                             object
# species                          object
# age                              object
# gender                           object
# size                             object
# coat                             object
# tags                             object
# name                             object
# description                      object
# organization_animal_id           object
# photos                           object
# videos                           object
# status                           object
# status_changed_at                object
# published_at                     object
# distance                        float64
# breeds.primary                   object
# breeds.secondary                 object
# breeds.mixed                       bool
# breeds.unknown                     bool
# ...

# %%
# Export data to csv file

pet_data.to_csv('Resources/data_import_test.csv', index=False)
